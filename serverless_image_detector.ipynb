# %%
import os
import boto3
import tensorflow as tf
import numpy as np

s3 = boto3.client('s3')

def upload_image(event, context):
    try:
        
        image_data = event['body']  
        
        if not is_valid_image(image_data):
            return {
                'statusCode': 400,
                'body': 'Invalid image file.'
            }

      
        image_name = generate_image_name()

     
        bucket_name = 'stenlihristov'
        s3.upload_fileobj(image_data, stenlihristov, image_name)

      
        image_url = f'https://{stenlihristov}.s3.amazonaws.com/{image_name}'

        return {
            'statusCode': 200,
            'body': image_url
        }
    except Exception as e:
        return {
            'statusCode': 500,
            'body': str(e)
        }


def identify_image(image_path):
    
    model = tf.keras.applications.ResNet50(weights='imagenet')

    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.resnet50.preprocess_input(img_array)

    predictions = model.predict(img_array)
    decoded_predictions = tf.keras.applications.resnet50.decode_predictions(predictions, top=3)[0]

    results = []
    for _, label, prob in decoded_predictions:
        results.append({
            'label': label,
            'probability': float(prob)
        })

        return results
        if(results == decoded_predictions){
            return True
        }else{
            return False
        }
